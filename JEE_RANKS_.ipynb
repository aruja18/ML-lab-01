# %% [markdown]
# <a href="https://colab.research.google.com/github/aruja18/ML-lab-01/blob/main/JEE_RANKS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('JEE_Rank_2016_2024.csv')
df
# Out:
#                                         Institute Quota  \
# 0      Indian Institute of Technology Bhubaneswar    AI
# 1           Indian Institute of Technology Bombay    AI
# 2           Indian Institute of Technology Bombay    AI
# 3           Indian Institute of Technology Bombay    AI
# 4           Indian Institute of Technology Bombay    AI
# ...                                           ...   ...
# 20829      Indian Institute of Technology Dharwad    AI
# 20830      Indian Institute of Technology Dharwad    AI
# 20831      Indian Institute of Technology Dharwad    AI
# 20832      Indian Institute of Technology Dharwad    AI
# 20833      Indian Institute of Technology Dharwad    AI
#
#                                       Gender  Year  \
# 0                             Gender-Neutral  2016
# 1                             Gender-Neutral  2016
# 2                             Gender-Neutral  2016
# 3                             Gender-Neutral  2016
# ...

# %%
# %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt
plt.xlabel('Year')
plt.ylabel('Closing_Rank')
plt.scatter(df.Year.astype(str),df['Closing_Rank'].astype(str),color='red',marker='+')

# %%
new_df = df.drop('Year',axis='columns')
new_df
# Out:
#                                         Institute Quota  \
# 0      Indian Institute of Technology Bhubaneswar    AI
# 1           Indian Institute of Technology Bombay    AI
# 2           Indian Institute of Technology Bombay    AI
# 3           Indian Institute of Technology Bombay    AI
# 4           Indian Institute of Technology Bombay    AI
# ...                                           ...   ...
# 20829      Indian Institute of Technology Dharwad    AI
# 20830      Indian Institute of Technology Dharwad    AI
# 20831      Indian Institute of Technology Dharwad    AI
# 20832      Indian Institute of Technology Dharwad    AI
# 20833      Indian Institute of Technology Dharwad    AI
#
#                                       Gender  \
# 0                             Gender-Neutral
# 1                             Gender-Neutral
# 2                             Gender-Neutral
# 3                             Gender-Neutral
# 4                             Gender-Neutral
# ...

# %%
Closing_Rank = df.Year
Closing_Rank
# Out:
# 0        2016
# 1        2016
# 2        2016
# 3        2016
# 4        2016
#          ...
# 20829    2024
# 20830    2024
# 20831    2024
# 20832    2024
# 20833    2024
# Name: Year, Length: 20834, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder

df = pd.read_csv('JEE_Rank_2016_2024.csv')
df.head()
new_df = df.drop(['Institute', 'Year'], axis=1)
Closing_Rank = df['Closing_Rank']
reg.fit(new_df, Closing_Rank)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e21b63878e29> in <cell line: 8>()
#       6 new_df = df.drop(['Institute', 'Year'], axis=1)
#       7 Closing_Rank = df['Closing_Rank']
# ----> 8 reg.fit(new_df, Closing_Rank)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     607         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     608
# --> 609         X, y = self._validate_data(
#     610             X,
#     611             y,
#
# ...

# %% [markdown]
# **(1) Predict price of a home with area = 3300 sqr ft**

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-bc5d2a149248> in <cell line: 1>()
# ----> 1 reg.predict([[3300]])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     304             Returns predicted values.
#     305         """
# --> 306         return self._decision_function(X)
#     307
#     308     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     284
#     285         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# --> 286         coef_ = self.coef_
# ...

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %% [markdown]
# **Y = m * X + b (m is coefficient and b is intercept)**

# %%
3300*135.78767123 + 180616.43835616432
# Out:
# 628715.7534151643

# %% [markdown]
# **(1) Predict price of a home with area = 5000 sqr ft**

# %%
reg.predict([[5000]])
# Out:
# array([859554.79452055])

# %% [markdown]
# <h3 style="color:purple">Generate CSV file with list of home price predictions</h3>

# %%
area_df = pd.read_csv("areas.csv")
area_df.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(area_df)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
area_df['prices']=p
area_df
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
area_df.to_csv("prediction.csv")

# %% [markdown]
# <h3>Exercise</h3>

# %% [markdown]
# <p >Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020</p>

# %% [markdown]
# <h3>Answer</h3>

# %% [markdown]
# 41288.69409442
